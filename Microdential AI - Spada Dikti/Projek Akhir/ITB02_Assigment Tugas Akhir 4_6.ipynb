# %% [markdown]
# ### Data Exploration and Preprocessing

# %%
import pandas as pd
import numpy as np
from collections import Counter

# %% [markdown]
# Membaca dataset

# %%
df= pd.read_csv('gaikindo6.csv', na_values=['-','0'])

df
# Out:
#        CAR TYPE  CC AND FUEL TYPE                        ASSEMBLER   BRAND  \
# 0    SEDAN TYPE  CC < 1.500 [G/D]  PT. Toyota Motor Mftg Indonesia  TOYOTA
# 1           NaN               NaN                              NaN     NaN
# 2           NaN               NaN                              NaN     NaN
# 3           NaN               NaN                              NaN     NaN
# 4           NaN               NaN                              NaN     NaN
# ..          ...               ...                              ...     ...
# 486         NaN               NaN                              NaN     NaN
# 487         NaN               NaN                              NaN     NaN
# 488         NaN               NaN                              NaN     NaN
# 489         NaN               NaN                              NaN     NaN
# 490         NaN               NaN                              NaN     NaN
#
# ...

# %% [markdown]
# Menampilkan shape (baris x kolom) dari df

# %%
df.shape
# Out:
# (491, 38)

# %% [markdown]
# Menampilkan kolom-kolom dari df

# %%
df.columns
# Out:
# Index(['CAR TYPE', 'CC AND FUEL TYPE', 'ASSEMBLER', 'BRAND', 'TYPE / MODEL',
#        'CC', 'TRANS', 'FUEL (G/D)', 'TANK CAPT', 'GVW (Kg)', 'GEAR RATIO',
#        'WHEEL & TYRE SIZE', 'PS / HP', 'WHEEL BASE', 'DIMENSION P x L x T',
#        'SEATER', 'DRIVE SYS.', 'Unnamed: 17', 'SPEED', 'DOOR', 'WHEELS', 'CBU',
#        'ORIGIN COUNTRY', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'Segmt Share', 'Sedan Share',
#        'TOTAL 2020'],
#       dtype='object')

# %% [markdown]
# Kita tidak membutuhkan data penjualan per bulan maupun per tahun, maka kita menghapus kolom-kolom tersebut

# %%
df= df.loc[:,:'ORIGIN COUNTRY']

df
# Out:
#        CAR TYPE  CC AND FUEL TYPE                        ASSEMBLER   BRAND  \
# 0    SEDAN TYPE  CC < 1.500 [G/D]  PT. Toyota Motor Mftg Indonesia  TOYOTA
# 1           NaN               NaN                              NaN     NaN
# 2           NaN               NaN                              NaN     NaN
# 3           NaN               NaN                              NaN     NaN
# 4           NaN               NaN                              NaN     NaN
# ..          ...               ...                              ...     ...
# 486         NaN               NaN                              NaN     NaN
# 487         NaN               NaN                              NaN     NaN
# 488         NaN               NaN                              NaN     NaN
# 489         NaN               NaN                              NaN     NaN
# 490         NaN               NaN                              NaN     NaN
#
# ...

# %%
df.isna().sum()
# Out:
# CAR TYPE               484
# CC AND FUEL TYPE       477
# ASSEMBLER              438
# BRAND                  438
# TYPE / MODEL             0
# CC                      55
# TRANS                   65
# FUEL (G/D)               2
# TANK CAPT              108
# GVW (Kg)               138
# GEAR RATIO             182
# WHEEL & TYRE SIZE       95
# PS / HP                109
# WHEEL BASE             106
# DIMENSION P x L x T    107
# SEATER                  89
# DRIVE SYS.               1
# Unnamed: 17              6
# SPEED                  369
# DOOR                    13
# WHEELS                   0
# CBU                      0
# ORIGIN COUNTRY           3
# dtype: int64

# %% [markdown]
# Menghapus kolom-kolom lain yang bersifat redundant, memiliki terlalu banyak nilai NaN atau tidak berpengaruh pada model

# %%
df.drop(['CC AND FUEL TYPE', 'ASSEMBLER', 'GEAR RATIO', 'PS / HP', 'WHEEL BASE', 'Unnamed: 17', 'CBU', 'ORIGIN COUNTRY','SPEED','WHEEL & TYRE SIZE'], axis=1, inplace=True)

df
# Out:
#        CAR TYPE   BRAND         TYPE / MODEL    CC TRANS FUEL (G/D)  \
# 0    SEDAN TYPE  TOYOTA   VIOS D (LOW GRADE)  1500    MT          G
# 1           NaN     NaN   VIOS R (MID GRADE)  1500    MT          G
# 2           NaN     NaN   VIOS D (LOW GRADE)  1500   CVT          G
# 3           NaN     NaN   VIOS R (MID GRADE)  1500   CVT          G
# 4           NaN     NaN  VIOS G (HIGH GRADE)  1500   CVT          G
# ..          ...     ...                  ...   ...   ...        ...
# 486         NaN     NaN           CALYA (3R)  1200   NaN          G
# 487         NaN     NaN           CALYA (3S)  1200   NaN          G
# 488         NaN     NaN           CALYA (3T)  1200   NaN          G
# 489         NaN     NaN           CALYA (3V)  1200   NaN          G
# 490         NaN     NaN           CALYA (3W)  1200   NaN          G
#
#      TANK CAPT GVW (Kg) DIMENSION P x L x T SEATER DRIVE SYS.  DOOR  WHEELS
# ...

# %% [markdown]
# Menampilkan deskripsi statistik df yang sekarang

# %%
df.describe()
# Out:
#         TANK CAPT        DOOR      WHEELS
# count  383.000000  478.000000  491.000000
# mean    73.929504    3.937238    4.696538
# std     61.845930    1.240576    1.609781
# min     33.000000    2.000000    4.000000
# 25%     45.000000    2.000000    4.000000
# 50%     50.000000    4.000000    4.000000
# 75%     80.000000    5.000000    4.000000
# max    405.000000    5.000000   10.000000

# %% [markdown]
# Handle Missing Value

# %% [markdown]
# Meng-copy ke bawah data car type dan brand. Maksudnya jika nilai car type atau brand suatu baris adalah NaN, maka baris tersebut akan menyalin nilai car type atau brand di atasnya

# %%
def copy_data_down(col):
    temp_brand= ''

    for i in df.index:
        if(df.loc[i, col] is not np.nan):
            temp_brand= df.loc[i, col]
        else:
            df.loc[i, col]= temp_brand

# %%
copy_data_down('CAR TYPE')
copy_data_down('BRAND')

# %% [markdown]
# Lalu menampilkan 20 baris pertama pada df yang telah diubah

# %%
df.head(20)
# Out:
#       CAR TYPE             BRAND         TYPE / MODEL    CC TRANS FUEL (G/D)  \
# 0   SEDAN TYPE            TOYOTA   VIOS D (LOW GRADE)  1500    MT          G
# 1   SEDAN TYPE            TOYOTA   VIOS R (MID GRADE)  1500    MT          G
# 2   SEDAN TYPE            TOYOTA   VIOS D (LOW GRADE)  1500   CVT          G
# 3   SEDAN TYPE            TOYOTA   VIOS R (MID GRADE)  1500   CVT          G
# 4   SEDAN TYPE            TOYOTA  VIOS G (HIGH GRADE)  1500   CVT          G
# 5   SEDAN TYPE            TOYOTA   VIOS R (MID GRADE)  1500   CVT          G
# 6   SEDAN TYPE            TOYOTA   VIOS D (LOW GRADE)  1500    MT          G
# 7   SEDAN TYPE            TOYOTA  VIOS G (HIGH GRADE)  1500    MT          G
# 8   SEDAN TYPE            TOYOTA   VIOS R (MID GRADE)  1500    MT          G
# 9   SEDAN TYPE            TOYOTA  VIOS G (HIGH GRADE)  1500   CVT          G
# 10  SEDAN TYPE            TOYOTA   VIOS R (MID GRADE)  1500   CVT          G
# ...

# %% [markdown]
# Mem-print brand beserta type / model setiap baris untuk melihat pola penamaan type / model setiap brand

# %%
for i in df.index:
    print(df.loc[i,'BRAND'], df.loc[i,'TYPE / MODEL'])
# Out:
# TOYOTA VIOS D (LOW GRADE)
# TOYOTA VIOS R (MID GRADE)
# TOYOTA VIOS D (LOW GRADE)
# TOYOTA VIOS R (MID GRADE)
# TOYOTA VIOS G (HIGH GRADE)
# TOYOTA VIOS R (MID GRADE)
# TOYOTA VIOS D (LOW GRADE)
# TOYOTA VIOS G (HIGH GRADE)
# TOYOTA VIOS R (MID GRADE)
# TOYOTA VIOS G (HIGH GRADE)
# TOYOTA VIOS R (MID GRADE)
# BMW BMW 320
# BMW BMW 328/330
# BMW BMW 520
# BMW BMW 528/530
# BMW BMW 7 series
# MERCEDES-BENZ PC C180
# MERCEDES-BENZ PC C 200 AVA
# MERCEDES-BENZ PC C 300 AMG
# MERCEDES-BENZ PC E 200 AVA
# MERCEDES-BENZ PC E 300 AVA
# MERCEDES-BENZ PC E 350 AMG
# MERCEDES-BENZ PC S 450
# DAIHATSU Grand New  Xenia 1.3 X MT
# DAIHATSU Grand New  Xenia 1.3 X AT
# DAIHATSU Grand New  Xenia 1.3 R MT
# DAIHATSU Grand New  Xenia 1.3 R AT
# DAIHATSU Grand New  Xenia 1.5 R MT
# DAIHATSU Grand New  Xenia 1.5 R AT
# DAIHATSU Luxio 1.5 D (New )
# DAIHATSU Luxio 1.5 X MT (New )
# DAIHATSU Luxio 1.5 X AT (New )
# DAIHATSU All New  Terios X AT
# DAIHATSU All New  Terios R MT
# ...

# %% [markdown]
# Mendefinisikan satu-satu model type valid

# %%
valid_model_type= ['TOYOTA VIOS', 'BMW 3', 'BMW 5', 'BMW 7', 'MERCEDES-BENZ PC', 'DAIHATSU Grand New  Xenia', 'DAIHATSU Luxio', 'DAIHATSU All New Terios', 'DAIHATSU Gran Max', 'DFSK GLORY', 'HONDA All New Jazz', 'HONDA New  Mobilio', 'HONDA HR-V', 'HONDA BR-V', 'HONDA All New CR-V', 'HONDA Brio', 'MITSUBISHI MOTORS', 'SUZUKI APV', 'SUZUKI All New Ertiga', 'SUZUKI XL07', 'TOYOTA YARIS', 'TOYOTA Sienta', 'TOYOTA AVANZA', 'TOYOTA RUSH', 'WULING Confero', 'WULING Cortez', 'WULING Formo', 'WULING Almaz', 'WULING Captiva', 'BMW X1', 'MINI Cooper', 'DFSK GLORY', 'HYUNDAI HIM', 'ISUZU Panther', 'TOYOTA INNOVA', 'TOYOTA FORTUNER', 'BMW X3', 'BMW X5', 'BMW X7', 'HINO FB', 'HINO WU', 'MITSUBISHI FUSO', 'HINO AK', 'HINO RK', 'HINO FC', 'HINO RN', 'MERCEDES-BENZ CV', 'ISUZU Traga', 'SUZUKI New Carry', 'DFSK DXK', 'HINO XZU', 'ISUZU NQR', 'ISUZU NMR', 'ISUZU NPS', 'ISUZU FRR', 'ISUZU NLR', 'TOYOTA DYNA', 'HINO FG', 'ISUZU FVR', 'ISUZU GVR', 'ISUZU FTR', 'HINO FL', 'HINO FM', 'ISUZU GVZ', 'ISUZU FVZ', 'ISUZU GXZ', 'ISUZU FVM', 'UD GKE', 'UD CDE', 'UD CWE', 'UD GWE', 'DAIHATSU New Ayla', 'DAIHATSU New Sigra', 'DATSUN GO', 'HONDA Brio', 'SUZUKI Karimun', 'TOYOTA AGYA', 'TOYOTA CALYA', 'TOYOTA TOWN / LITE', 'HINO SG']
valid_model_type_by_brand= {}

for i in valid_model_type:
    j= i.split(' ')
    brand= j[0].upper()
    type_model= (' '.join([str(i) for i in j[1:]])).upper().replace('  ', ' ')
    
    if(brand not in valid_model_type_by_brand):
        valid_model_type_by_brand[brand]= set([])
        
    valid_model_type_by_brand[brand].add(type_model)

# %% [markdown]
# Menampilkan model type valid

# %%
valid_model_type_by_brand
# Out:
# {'TOYOTA': {'AGYA',
#   'AVANZA',
#   'CALYA',
#   'DYNA',
#   'FORTUNER',
#   'INNOVA',
#   'RUSH',
#   'SIENTA',
#   'TOWN / LITE',
#   'VIOS',
#   'YARIS'},
#  'BMW': {'3', '5', '7', 'X1', 'X3', 'X5', 'X7'},
#  'MERCEDES-BENZ': {'CV', 'PC'},
#  'DAIHATSU': {'ALL NEW TERIOS',
#   'GRAN MAX',
#   'GRAND NEW XENIA',
#   'LUXIO',
#   'NEW AYLA',
#   'NEW SIGRA'},
#  'DFSK': {'DXK', 'GLORY'},
#  'HONDA': {'ALL NEW CR-V',
#   'ALL NEW JAZZ',
#   'BR-V',
#   'BRIO',
#   'HR-V',
#   'NEW MOBILIO'},
#  'MITSUBISHI': {'FUSO', 'MOTORS'},
#  'SUZUKI': {'ALL NEW ERTIGA', 'APV', 'KARIMUN', 'NEW CARRY', 'XL07'},
#  'WULING': {'ALMAZ', 'CAPTIVA', 'CONFERO', 'CORTEZ', 'FORMO'},
#  'MINI': {'COOPER'},
#  'HYUNDAI': {'HIM'},
#  'ISUZU': {'FRR',
#   'FTR',
#   'FVM',
#   'FVR',
#   'FVZ',
#   'GVR',
#   'GVZ',
#   'GXZ',
#   'NLR',
#   'NMR',
#   'NPS',
#   'NQR',
#   'PANTHER',
#   'TRAGA'},
#  'HINO': {'AK', 'FB', 'FC', 'FG', 'FL', 'FM', 'RK', 'RN', 'SG', 'WU', 'XZU'},
# ...

# %% [markdown]
# Mengaplikasikan format type / model yang valid pada df. Lalu menyimpan nama jenis mobil + brand + type / model valid pada sebuah list

# %%
type_list= []
for i in df.index:
    p= 0
    res_list= []
    car_type= df.loc[i, 'CAR TYPE'].replace('TYPE','').strip()
    brand= df.loc[i,'BRAND'].upper()
    model_type= df.loc[i,'TYPE / MODEL'].upper().replace('  ', ' ')
    
    if(brand in valid_model_type_by_brand):
        for j in valid_model_type_by_brand[brand]:
            if(j in model_type):
                res_list.append(j)
                p+= 100
                
                
    else:
        for k in valid_model_type_by_brand.keys():
            if(k in brand):
                brand= k
                k.upper().replace('  ', ' ')
                break
        
        if(brand in ['MERCEDES-BENZ','MITSUBISHI','HYUNDAI']):
            for l in valid_model_type_by_brand[brand]:
                if(l in df.loc[i, 'BRAND']):
                    res_list.append(l)
                    p+= 10
                    
                
        else:
            for m in valid_model_type_by_brand[brand]:
                if(m in model_type):
                    res_list.append(m)
                    p+= 1
    
    if(len(res_list)>1):
        if('BMW' in model_type):
            model_type_temp= model_type.split(' ')
            if('X' in model_type_temp[1]):
                model_type2= ''.join([i for i in res_list if 'X' in i])
            else:
                model_type2= model_type_temp[1][0]

        if('HINO' in brand):
            for i in res_list:
                if(i==model_type[:2] or i==model_type[:3]):
                    model_type2= i
                    break
                
                
    if(len(res_list)>1):
        type_list.append(f'{car_type} {brand} {model_type2}')
    else:
        type_list.append(f'{car_type} {brand} {res_list[0]}')

# %% [markdown]
# Membuat kolom baru yang yang menampung tipe mobil (seperti sedan, truck, dll), brand, dan model. Nantinya kolom ini yang akan menjadi kolom target. Selanjutnya menghapus 3 kolom redundant tersebut

# %%
df['TYPE_BRAND_MODEL']= type_list
df2= df.copy()

df2.drop(['CAR TYPE', 'BRAND', 'TYPE / MODEL'], axis=1, inplace=True)

df2
# Out:
#        CC TRANS FUEL (G/D)  TANK CAPT GVW (Kg) DIMENSION P x L x T SEATER  \
# 0    1500    MT          G       42.0     1080      4410X1700X1475      5
# 1    1500    MT          G       42.0     1080      4410X1700X1475      5
# 2    1500   CVT          G       42.0     1080      4410X1700X1475      5
# 3    1500   CVT          G       42.0     1080      4410X1700X1475      5
# 4    1500   CVT          G       42.0     1080      4410X1700X1475      5
# ..    ...   ...        ...        ...      ...                 ...    ...
# 486  1200   NaN          G        NaN      NaN                 NaN      7
# 487  1200   NaN          G        NaN      NaN                 NaN      7
# 488  1200   NaN          G        NaN      NaN                 NaN      7
# 489  1200   NaN          G        NaN      NaN                 NaN      7
# 490  1200   NaN          G        NaN      NaN                 NaN      7
#
#     DRIVE SYS.  DOOR  WHEELS                                TYPE_BRAND_MODEL
# ...

# %% [markdown]
# Fitur ekstraksi

# %% [markdown]
# Mengekstrak panjang, lebar, dan tinggi dari kolom panjang x lebar x tinggi

# %%
length_list= []
width_list= []
height_list= []

for i in df2.index:
    dimension= df2.loc[i,'DIMENSION P x L x T']
    if(dimension is not np.nan):
        dimension_list= dimension.upper().split('X')
        if(len(dimension_list)==3):
            length_list.append(int(dimension_list[0].replace(',','').replace('.','').strip()))
            width_list.append(int(dimension_list[1].replace(',','').replace('.','').strip()))
            height_list.append(int(dimension_list[2].replace(',','').replace('.','').strip()))
        elif(len(dimension_list)==2):
            length_list.append(int(dimension_list[0].replace(',','').replace('.','').strip()))
            width_list.append(int(dimension_list[1].replace(',','').replace('.','').strip()))
            height_list.append(np.nan)
        elif(len(dimension_list)==1):
            length_list.append(dimension_list[0].replace(',','').replace('.','').strip())
            width_list.append(np.nan)
            height_list.append(np.nan)
    else:
        length_list.append(np.nan)
        width_list.append(np.nan)
        height_list.append(np.nan)

# %%
df2['LENGTH']= length_list
df2['WIDTH']= width_list
df2['HEIGHT']= height_list

df2.drop('DIMENSION P x L x T', axis=1, inplace=True)

# %%
df2.head(20)
# Out:
#       CC TRANS FUEL (G/D)  TANK CAPT GVW (Kg) SEATER DRIVE SYS.  DOOR  WHEELS  \
# 0   1500    MT          G       42.0     1080      5        4X2   4.0       4
# 1   1500    MT          G       42.0     1080      5        4X2   4.0       4
# 2   1500   CVT          G       42.0     1080      5        4X2   4.0       4
# 3   1500   CVT          G       42.0     1080      5        4X2   4.0       4
# 4   1500   CVT          G       42.0     1080      5        4X2   4.0       4
# 5   1500   CVT          G       42.0     1080      5        4X2   4.0       4
# 6   1500    MT          G       42.0     1080      5        4X2   4.0       4
# 7   1500    MT          G       42.0     1080      5        4X2   4.0       4
# 8   1500    MT          G       42.0     1080      5        4X2   4.0       4
# 9   1500   CVT          G       42.0     1080      5        4X2   4.0       4
# 10  1500   CVT          G       42.0     1080      5        4X2   4.0       4
# ...

# %% [markdown]
# Selanjutnya kita akan mengubah beberapa kolom bertipe objek menjadi float, namun sebelum itu kita perlu mengubah data tersebut menjadi data yang bisa diubah menjadi float (menghapus karakter-karakter string seperti '.', ',', '+', dll, melalui fungsi berikut

# %%
def validate_float(x):
    if(x is not np.nan):
        if('+' in x):
            return int(x.split('+')[0])+int(x.split('+')[1])
        else:
            return x.replace(',','').replace('.','').strip()
    else:
        return np.nan

# %%
for i in ['CC', 'GVW (Kg)', 'SEATER']:
    df2[i]= df2[i].map(validate_float).astype(float)

# %% [markdown]
# Merapikan data pada kolom transmission

# %%
def transmission_wrangling(x):
    if(x is np.nan):
        return x
    
    if('/' in x):
        if('A' in x):
            return 'AT'
        else:
            return 'MT'
    else:
        return x

df2['TRANS']= df2['TRANS'].map(transmission_wrangling)

# %% [markdown]
# Beberapa data pada kolom transmission dan fuel berbeda walaupun memiliki arti / nilai yang sama, maka dari itu kita perlu menyeragamkan data tersebut terlebih dahulu

# %%
def trans_change(x):
    if x is np.nan:
        return x
    
    if x=='MT':
        return 'Manual'
    elif x=='AT':
        return 'Otomatis'
    elif x=='CVT':
        return 'Transmisi CVT'
    
def fuel_change(x):
    if x is np.nan:
        return x
    
    if x=='G':
        return 'Bensin'
    elif x=='EV':
        return 'Listrik'
    elif x=='D':
        return 'Diesel'

# %%
df2['TRANS']= df2['TRANS'].map(trans_change)
df2['FUEL (G/D)']= df2['FUEL (G/D)'].map(fuel_change)

df2
# Out:
#          CC          TRANS FUEL (G/D)  TANK CAPT  GVW (Kg)  SEATER DRIVE SYS.  \
# 0    1500.0         Manual     Bensin       42.0    1080.0     5.0        4X2
# 1    1500.0         Manual     Bensin       42.0    1080.0     5.0        4X2
# 2    1500.0  Transmisi CVT     Bensin       42.0    1080.0     5.0        4X2
# 3    1500.0  Transmisi CVT     Bensin       42.0    1080.0     5.0        4X2
# 4    1500.0  Transmisi CVT     Bensin       42.0    1080.0     5.0        4X2
# ..      ...            ...        ...        ...       ...     ...        ...
# 486  1200.0            NaN     Bensin        NaN       NaN     7.0        4X2
# 487  1200.0            NaN     Bensin        NaN       NaN     7.0        4X2
# 488  1200.0            NaN     Bensin        NaN       NaN     7.0        4X2
# 489  1200.0            NaN     Bensin        NaN       NaN     7.0        4X2
# 490  1200.0            NaN     Bensin        NaN       NaN     7.0        4X2
#
# ...

# %%
df2.isna().sum()
# Out:
# CC                   55
# TRANS                65
# FUEL (G/D)            2
# TANK CAPT           108
# GVW (Kg)            138
# SEATER               89
# DRIVE SYS.            1
# DOOR                 13
# WHEELS                0
# TYPE_BRAND_MODEL      0
# LENGTH              107
# WIDTH               107
# HEIGHT              111
# dtype: int64

# %% [markdown]
# Mengurutkan ulang kolom target

# %%
temp= df2['TYPE_BRAND_MODEL']
df2.drop('TYPE_BRAND_MODEL', axis='columns', inplace=True)
df2['TYPE_BRAND_MODEL']= temp

df2
# Out:
#          CC          TRANS FUEL (G/D)  TANK CAPT  GVW (Kg)  SEATER DRIVE SYS.  \
# 0    1500.0         Manual     Bensin       42.0    1080.0     5.0        4X2
# 1    1500.0         Manual     Bensin       42.0    1080.0     5.0        4X2
# 2    1500.0  Transmisi CVT     Bensin       42.0    1080.0     5.0        4X2
# 3    1500.0  Transmisi CVT     Bensin       42.0    1080.0     5.0        4X2
# 4    1500.0  Transmisi CVT     Bensin       42.0    1080.0     5.0        4X2
# ..      ...            ...        ...        ...       ...     ...        ...
# 486  1200.0            NaN     Bensin        NaN       NaN     7.0        4X2
# 487  1200.0            NaN     Bensin        NaN       NaN     7.0        4X2
# 488  1200.0            NaN     Bensin        NaN       NaN     7.0        4X2
# 489  1200.0            NaN     Bensin        NaN       NaN     7.0        4X2
# 490  1200.0            NaN     Bensin        NaN       NaN     7.0        4X2
#
# ...

# %% [markdown]
# Categorical encoding

# %%
X= df2.drop('TYPE_BRAND_MODEL', axis='columns')
y= df2['TYPE_BRAND_MODEL']

df3= pd.concat([pd.get_dummies(X),y],axis=1)

df3
# Out:
#          CC  TANK CAPT  GVW (Kg)  SEATER  DOOR  WHEELS  LENGTH   WIDTH  \
# 0    1500.0       42.0    1080.0     5.0   4.0       4  4410.0  1700.0
# 1    1500.0       42.0    1080.0     5.0   4.0       4  4410.0  1700.0
# 2    1500.0       42.0    1080.0     5.0   4.0       4  4410.0  1700.0
# 3    1500.0       42.0    1080.0     5.0   4.0       4  4410.0  1700.0
# 4    1500.0       42.0    1080.0     5.0   4.0       4  4410.0  1700.0
# ..      ...        ...       ...     ...   ...     ...     ...     ...
# 486  1200.0        NaN       NaN     7.0   4.0       4     NaN     NaN
# 487  1200.0        NaN       NaN     7.0   4.0       4     NaN     NaN
# 488  1200.0        NaN       NaN     7.0   4.0       4     NaN     NaN
# 489  1200.0        NaN       NaN     7.0   4.0       4     NaN     NaN
# 490  1200.0        NaN       NaN     7.0   4.0       4     NaN     NaN
#
#      HEIGHT  TRANS_Manual  TRANS_Otomatis  TRANS_Transmisi CVT  \
# ...

# %% [markdown]
# Sekarang data telah siap untuk di-train, selanjutnya kita akan menggunakan xgboost classifier sebagai model karena modelnya yang bisa menangani nilai NaN serta menangani imbalance dataset

# %% [markdown]
# ### Membangun Model

# %% [markdown]
# Mengimport model xgboost

# %%
from xgboost import XGBClassifier

# %% [markdown]
# Mendefinisikan fitur dan target

# %%
X= df3.drop('TYPE_BRAND_MODEL', axis='columns').values
y= df3['TYPE_BRAND_MODEL'].values

X, y
# Out:
# (array([[1500.,   42., 1080., ...,    0.,    0.,    0.],
#         [1500.,   42., 1080., ...,    0.,    0.,    0.],
#         [1500.,   42., 1080., ...,    0.,    0.,    0.],
#         ...,
#         [1200.,   nan,   nan, ...,    0.,    0.,    0.],
#         [1200.,   nan,   nan, ...,    0.,    0.,    0.],
#         [1200.,   nan,   nan, ...,    0.,    0.,    0.]]),
#  array(['SEDAN TOYOTA VIOS', 'SEDAN TOYOTA VIOS', 'SEDAN TOYOTA VIOS',
#         'SEDAN TOYOTA VIOS', 'SEDAN TOYOTA VIOS', 'SEDAN TOYOTA VIOS',
#         'SEDAN TOYOTA VIOS', 'SEDAN TOYOTA VIOS', 'SEDAN TOYOTA VIOS',
#         'SEDAN TOYOTA VIOS', 'SEDAN TOYOTA VIOS', 'SEDAN BMW 3',
#         'SEDAN BMW 3', 'SEDAN BMW 5', 'SEDAN BMW 5', 'SEDAN BMW 7',
#         'SEDAN MERCEDES-BENZ PC', 'SEDAN MERCEDES-BENZ PC',
#         'SEDAN MERCEDES-BENZ PC', 'SEDAN MERCEDES-BENZ PC',
#         'SEDAN MERCEDES-BENZ PC', 'SEDAN MERCEDES-BENZ PC',
#         'SEDAN MERCEDES-BENZ PC', '4X2 DAIHATSU GRAND NEW XENIA',
# ...

# %% [markdown]
# Melakukan train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(X, y, test_size=0.2)

x_train, y_train
# Out:
# (array([[1.498e+03, 5.800e+01, 2.035e+03, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [1.500e+03, 4.500e+01, 1.085e+03, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [7.684e+03,       nan, 1.510e+04, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         ...,
#         [4.009e+03,       nan, 5.200e+03, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [7.684e+03,       nan, 1.510e+04, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [2.700e+03, 8.000e+01,       nan, ..., 1.000e+00, 0.000e+00,
#          0.000e+00]]),
#  array(['4X2 DFSK GLORY', '4X2 TOYOTA AVANZA', 'TRUCK HINO FG',
#         'AFFORDABLE ENERGY SAVING CARS 4X2 TOYOTA AGYA',
#         '4X2 SUZUKI ALL NEW ERTIGA', '4X2 SUZUKI ALL NEW ERTIGA',
#         '4X2 TOYOTA FORTUNER',
#         'AFFORDABLE ENERGY SAVING CARS 4X2 DAIHATSU NEW AYLA',
#         'TRUCK MITSUBISHI FUSO', 'TRUCK HINO XZU', '4X4 TOYOTA FORTUNER',
# ...

# %% [markdown]
# Melakukan train pada data train

# %%
xgb_model = XGBClassifier(random_state=0, max_delta_step=1)
xgb_model.fit(x_train, y_train)

y_predict= xgb_model.predict(x_test)
# Out:
# c:\users\lenovo\pycharmprojects\data science\venv\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:06:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# Evaluasi

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

accuracy_score(y_test, y_predict)
# Out:
# 0.8484848484848485

# %%
cm= confusion_matrix(y_test, y_predict)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Karena kita melakukan encode dengan one hot encode, maka kita perlu melakukan beberapa validasi yang dirangkum pada fungsi di bawah

# %%
def validate_new_data(data):
    global df2
    global df3
    
    col_list= df2.columns[:-1]
    col_list2= df3.columns[:-1]
    new_data= pd.DataFrame([data], columns= col_list)

    new_data= pd.get_dummies(new_data)
    missing_columns = set(col_list2) - set(new_data.columns)

    for i in missing_columns:
        new_data[i] = 0

    new_data = new_data[col_list2].values
    
    return new_data

# %% [markdown]
# Membuat fungsi prediksi

# %%
def pred(data):
    global xgb_model

    data= validate_new_data(data)
    pred_y= xgb_model.predict(data)

    return pred_y

# %% [markdown]
# Melakukan fit pada keseluruhan data

# %%
xgb_model = XGBClassifier(random_state=0, max_delta_step=1)
xgb_model.fit(X, y)
# Out:
# c:\users\lenovo\pycharmprojects\data science\venv\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:06:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
# ...
